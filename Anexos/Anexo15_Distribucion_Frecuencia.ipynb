# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#Individuos = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/BDIndividuosTotal.csv',decimal=',')
Individuos = pd.read_csv(r'/content/BDIndividuosTotal.csv',decimal=',')
Individuos['IPCM'] = Individuos['IPCM'].astype(float)
Individuos
# Out:
#        S_1        I_6   I_7                                             I_8  \
# 0        1   Femenino  1985                          Sin pertenencia étnica
# 1        1  Masculino  1953                          Sin pertenencia étnica
# 2        1   Femenino  1970                          Sin pertenencia étnica
# 3        1   Femenino  1989                          Sin pertenencia étnica
# 4        1   Femenino  1953                                         Mestizo
# ...    ...        ...   ...                                             ...
# 11356   12     Hombre  1999  No se identifica con ninguno de los anteriores
# 11357   12     Hombre  1994                                         Mestizo
# 11358   12     Hombre  1968  No se identifica con ninguno de los anteriores
# 11359   12     Hombre  1998  No se identifica con ninguno de los anteriores
# 11360   12     Hombre  1997  No se identifica con ninguno de los anteriores
#
# ...

# %%
fig = px.box(Individuos, x="I_41", y="IPCM", points="all", color= "I_41", title="Durante los últimos 24 meses, ¿Usted ha participado en iniciativas, propuestas" + "<br>" + "o proyectos que beneficien su comuna o corregimiento?",
            labels={"I_41":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Individuos, x="I_52", y="IPCM", points="all", color= "I_52", title="¿Participa usted en la toma de decisiones para mejorar su comuna o corregimiento?",
            labels={"I_52":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Organizaciones = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/BDOrganizacionesTotal.csv',decimal=',')
Organizaciones = pd.read_csv(r'/content/BDOrganizacionesTotal.csv',decimal=',')
Organizaciones['IPCM'] = Organizaciones['IPCM'].astype(float)
Organizaciones
# Out:
#       Edicion  S_1    O_88 O_89 O_12 O_13  O_22             O_67  \
# 0        2019    1  Hombre   Si   Si   No   300      No consulta
# 1        2019    1   Mujer   No   Si   Si    50      No consulta
# 2        2019    1  Hombre   No   Si   Si  3000    Algunas veces
# 3        2019    1   Mujer   No   Si   Si    30      No consulta
# 4        2019    1   Mujer   Si   Si   Si    12    Algunas veces
# ...       ...  ...     ...  ...  ...  ...   ...              ...
# 2834     2021   11  Hombre   Si   No   No    50      No consulta
# 2835     2021   11  Hombre   No   No   No    49      No consulta
# 2836     2021   11  Hombre   Si   No   No    15      No consulta
# 2837     2021   11   Mujer   Si   No   No    10      No consulta
# 2838     2021   10   Mujer   Si   Si   Si    30  Muy pocas veces
#
#                  O_68 O_8  ...                 O_62_3                 O_62_4  \
# 0         No consulta  No  ...                Neutral                Neutral
# ...

# %%
fig = px.box(Organizaciones, x="O_72_9", y="IPCM", points="all", color= "O_72_9", title="Cuando su organización o colectivo social busca información sobre los programas y proyectos" + "<br>" + "de la Alcaldía de Medellín, puede observar: j. no busca",
            labels={"O_72_9":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_72_8", y="IPCM", points="all", color= "O_72_8", title="Cuando su organización o colectivo social busca información sobre los programas y proyectos" + "<br>" + "de la Alcaldía de Medellín, puede observar: i. No encuentra",
            labels={"O_72_8":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_20_7", y="IPCM", points="all", color= "O_20_7", title="Su organización y/o colectivo social ha recibido alguna intimidación o han experimentado" + "<br>" + "situaciones que impliquen o le obliguen a: g. Pagar extorsión o vacuna",
            labels={"O_20_7":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_20_6", y="IPCM", points="all", color= "O_20_6", title="Su organización y/o colectivo social ha recibido alguna intimidación o han experimentado" + "<br>" + "situaciones que impliquen o le obliguen a: f. Expulsión de algún miembro",
            labels={"O_20_6":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_20_1", y="IPCM", points="all", color= "O_20_1", title="Su organización y/o colectivo social ha recibido alguna intimidación o han experimentado" + "<br>" + "situaciones que impliquen o le obliguen a: a. Cerrar el grupo",
            labels={"O_20_1":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_20_5", y="IPCM", points="all", color= "O_20_5", title="Su organización y/o colectivo social ha recibido alguna intimidación o han experimentado" + "<br>" + "situaciones que impliquen o le obliguen a: e. Irse del barrio, de la comuna o corregimiento",
            labels={"O_20_5":""})
fig.update_layout(
    title={        
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_62_2", y="IPCM", points="all", color= "O_62_2", title="Califique de 1 a 5, siendo 1 totalmente inequitativo y 5 totalmente equitativo. Cree usted que las acciones" + "<br>" + "realizadas por las organizaciones y/o los colectivos de la comuna o corregimiento," + "<br>" + "en términos de recursos, obras y garantía de derechos, son equitativas entre:" + "<br>" + "b.   Veredas del corregimiento vs centralidad del corregimiento",
            labels={"O_62_2":""})
fig.update_layout(
    title={        
        'y':0.96,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_62_1", y="IPCM", points="all", color= "O_62_1", title="Califique de 1 a 5, siendo 1 totalmente inequitativo y 5 totalmente equitativo. Cree usted que las acciones" + "<br>" + "realizadas por las organizaciones y/o los colectivos de la comuna o corregimiento," + "<br>" + "en términos de recursos, obras y garantía de derechos, son equitativas entre:" + "<br>" + "a.   Barrios de la comuna o corregimiento",
            labels={"O_62_1":""})
fig.update_layout(
    title={        
        'y':0.96,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(Organizaciones, x="O_61_1", y="IPCM", points="all", color= "O_61_1", title="Califique de 1 a 5, siendo 1 totalmente inequitativo y 5 totalmente equitativo. Cree usted que las acciones" + "<br>" + "realizadas por la Administración Municipal en términos de recursos, obras y garantía de derechos," + "<br>" + "son equitativas entre: a. Comunas o corregimientos",
            labels={"O_61_1":""})
fig.update_layout(
    title={        
        'y':0.96,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
