# %%
import pandas as pd
import numpy as np

# %%
db2019 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2019/dataPublica_individuos.csv') #Lectura del archivo que contiene los datos de Individuos que participan del año 2019.
#encabezado = db2019.iloc[0]
db2019 = db2019.rename(columns=db2019.iloc[0]) #Se cambia el nombre de las columnas a partir de la primera fila
db2019 = db2019.drop(db2019.index[0]) #Se elimina la primera fila para evitar que se duplique el nombre de la columna
db2019 = db2019.drop(columns = ['Date.Collected', 'Date.Sent', 'Duration.(seconds)', 'User', 'Latitude', 'Longitude', 'Comuna', 'cm', 'I_3', 'S_1','I_28','I_35']) #Se eliminan columnas innecesarias para la medición del IPCM.
db2019 = db2019.rename(columns={'CodComuna':'S_1'}) # Se renombra la columna "CodComuna" y se le otorga el código correspondiente "S_1"
db2019.insert(0, "Edicion", 2019, allow_duplicates=False) #Se le agrega la columna Edición al inicio de la tabla, y se le otorga a todos los registros el año de la medición (2019)
db2019 = db2019.reset_index(drop=True) #Se reinicia el índice de la tabla
db2019 = db2019[['S_1', 'I_6', 'I_7', 'I_8', 'I_9', 'I_10',
          "I_19",	"I_21_1",	"I_21_2",	"I_21_3", "I_22",	"I_23",	"I_24",	"I_26_1",	"I_26_2","I_26_3", "I_27",	"I_28_1", "I_29",
          "I_32",	"I_33",	"I_40_1", "I_40_2", "I_40_3", "I_40_4", "I_40_5",	"I_90_1", "I_90_2","I_90_3","I_90_4","I_90_5","I_90_6","I_90_7",
          "I_90_8","I_90_9","I_90_10",
          "I_31",	"I_35_1", "I_38",	"I_51_2", "I_51_3",	"I_51_4",	"I_52",	"I_54", "I_55",	"I_48_1", "I_48_2", "I_48_3", "I_48_4", "I_48_5",
          "I_48_6","I_48_7","I_48_8","I_48_9", "I_91_1","I_91_2","I_91_3","I_91_4","I_91_5","I_91_6","I_91_7","I_91_8","I_91_9","I_91_10",
          "I_30",	"I_41",	"I_44",	"I_45","I_47"]]
db2019
#db2019['I_62_7'].unique()
# Out:
#      S_1        I_6   I_7                     I_8  \
# 0      1   Femenino  1985  Sin pertenencia étnica
# 1      1  Masculino  1953  Sin pertenencia étnica
# 2      1   Femenino  1970  Sin pertenencia étnica
# 3      1   Femenino  1989  Sin pertenencia étnica
# 4      1   Femenino  1953                 Mestizo
# ...   ..        ...   ...                     ...
# 3634  90  Masculino  1993  Sin pertenencia étnica
# 3635  90  Masculino  2000  Sin pertenencia étnica
# 3636  90   Femenino  1996  Sin pertenencia étnica
# 3637  90  Masculino  1996  Sin pertenencia étnica
# 3638  90  Masculino  1955  Sin pertenencia étnica
#
#                                              I_9               I_10 I_19  \
# 0     Desplazados o víctima del Conflicto Armado  Básica Secundaria   Si
# 1                                        Ninguno    Básica Primaria   No
# 2     Desplazados o víctima del Conflicto Armado            Ninguno   No
# ...

# %%
IPCM_I_2019 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2019/Indiviudos Indicador Global Gifi Demografico.csv', header=None) #Lectura del archivo donde están contenidos los resultados de la medición del año 2019 por cada individuo (Índices y Subíndices)
IPCM_I_2019 = IPCM_I_2019.drop(range(0,10))
IPCM_I_2019 = IPCM_I_2019.rename(columns=IPCM_I_2019.iloc[0]) #Se cambia el nombre de la columna a partir de la primera fila.
IPCM_I_2019 = IPCM_I_2019.drop(IPCM_I_2019.index[0]) #Se elimina la primera fila para evitar que se duplique el nombre de la columna
IPCM_I_2019.Orden = IPCM_I_2019.Orden.astype(int) #Se agrega la columna orden para poder ordenar los registros de modo que coincidan con la base de datos de Individuos 2019 ("dataPublica_individuos.csv")
IPCM_I_2019 = IPCM_I_2019.sort_values('Orden') #Se ordenan los registros a partir de la columna Orden
IPCM_I_2019 = IPCM_I_2019.reset_index(drop=True) #Se reinicia el índice de la tabla
IPCM_I_2019
# Out:
#       Orden          Comuna                           Barrio  ComunaParticipa  \
# 0         1       1 POPULAR          La 1001011\tLA AVANZADA       1\tPOPULAR
# 1         2       1 POPULAR                              NaN       1\tPOPULAR
# 2         3       1 POPULAR                         Chispero              NaN
# 3         4       1 POPULAR                               Ca       1\tPOPULAR
# 4         5       1 POPULAR  1001001\tSANTO DOMINGO SABIO Nº       1\tPOPULAR
# ...     ...             ...                              ...              ...
# 3634   3640  90 SANTA ELENA                         El Tambo              NaN
# 3635   3641  90 SANTA ELENA                              NaN              NaN
# 3636   3642  90 SANTA ELENA                        El Placer              NaN
# 3637   3643  90 SANTA ELENA                            Barro              NaN
# 3638   3644  90 SANTA ELENA                      Vereda Mazo  90\tSANTA ELENA
#
# ...

# %%
db2019.insert(69, "Condiciones Territoriales", IPCM_I_2019['Global C'], allow_duplicates=False) #Se inserta en la tabla de Individuos 2019 una columna denominada "Condiciones Territoriales", que contiene el puntaje del Índice por esta dimensión
db2019.insert(70, "Prácticas", IPCM_I_2019['Global P'], allow_duplicates=False) #Se inserta en la tabla de Individuos 2019 una columna denominada "Prácticas", que contiene el puntaje del Índice por esta dimensión
db2019.insert(71, "Efectos", IPCM_I_2019['Global E'], allow_duplicates=False) #Se inserta en la tabla de Individuos 2019 una columna denominada "Efectos", que contiene el puntaje del Índice por esta dimensión
db2019.insert(72, "IPCM", IPCM_I_2019['Indice de Participación 3'], allow_duplicates=False) #Se insertan en la tabla de Individuos 2019 una columna denominada "IPCM", que contiene el puntaje global del Índice de Participación Ciudadana
db2019[['Condiciones Territoriales','Prácticas','Efectos','IPCM']] = db2019[['Condiciones Territoriales','Prácticas','Efectos','IPCM']].replace(',','.', regex=True)
db2019[['Condiciones Territoriales','Prácticas','Efectos','IPCM']] = db2019[['Condiciones Territoriales','Prácticas','Efectos','IPCM']].astype(float)
db2019
# Out:
#      S_1        I_6   I_7                     I_8  \
# 0      1   Femenino  1985  Sin pertenencia étnica
# 1      1  Masculino  1953  Sin pertenencia étnica
# 2      1   Femenino  1970  Sin pertenencia étnica
# 3      1   Femenino  1989  Sin pertenencia étnica
# 4      1   Femenino  1953                 Mestizo
# ...   ..        ...   ...                     ...
# 3634  90  Masculino  1993  Sin pertenencia étnica
# 3635  90  Masculino  2000  Sin pertenencia étnica
# 3636  90   Femenino  1996  Sin pertenencia étnica
# 3637  90  Masculino  1996  Sin pertenencia étnica
# 3638  90  Masculino  1955  Sin pertenencia étnica
#
#                                              I_9               I_10 I_19  \
# 0     Desplazados o víctima del Conflicto Armado  Básica Secundaria   Si
# 1                                        Ninguno    Básica Primaria   No
# 2     Desplazados o víctima del Conflicto Armado            Ninguno   No
# ...

# %%
db2017 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2017/BD_ParticipantesV20180404.csv') #Lectura del archivo que contiene los datos de Individuos 2017. Se lee en segundo lugar porque al ser la versión más antigua, la normalización se realiza en base a 2019.
db2017 = db2017.drop(1).drop(0) #Se eliminan las dos primeras filas
db2017 = db2017.drop(db2017[db2017['I_13']=='-55'].index) #Se eliminan los registros de la columna "I_13" que contiene datos nulos (-55). Esta columna contiene la siguiente pregunta: En los últimos 24 meses, usted ha pertenecido a alguna organización con personería jurídica, que representa, gestiona o defiende los derechos e intereses de la gente.
db2017 = db2017.drop(columns = ['S_00', 'I_3', 'I_4', 'I_5', 'I_6c','I_9_2','I_12','I_17','I_17_5c','I_18','I_19c','I_22c','I_23c','I_26','I_39_2c']) #Se eliminan las columnas que no tienen aporte al cálculo del IPCM
db2017 = db2017.rename(columns={'I_9_1':'I_9', 'Unnamed: 0':'Orden'}) #Se renombran las columnas para que coincidan en nombre con la base de datos de 2019
# db2017.Orden = db2017.Orden.astype(int)
db2017.insert(0, "Edicion", 2017, allow_duplicates=False) #Se le agrega la columna Edición al inicio de la tabla, y se le otorga a todos los registros el año de la medición (2017)
db2017['I_7'] = db2017['I_7'].str[6:10] #Se editan los registros de la columna "I_7" para que sólo se muestre el año de nacimiento.
db2017['I_6'] = db2017['I_6'].map({'1':'Masculino', '2':'Femenino', '3':'Otro'}) #Se editan los registros de la columna "I_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_8'] = db2017['I_8'].map({'1':'Afrodescendiente', '2':'Palenqueros', '3':'Raizal-Sanandresano','4':'Indígena','5':'Rom o gitano','-88':'Sin pertenencia étnica'}) #Se editan los registros de la columna "I_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_9'] = db2017['I_9'].map({'1':'LGBTI', '2':'Víctima del Conflicto Armado', '3':'Diversidad funcional o discapacitado','4':'Población en situación de calle','5':'Madre cabeza de hogar','6':'Desplazado','7':'Desmovilizados','8':'Ninguno'}) #Se editan los registros de la columna "I_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_10'] = db2017['I_10'].map({'1':'Ninguno', '2':'Básica Primaria', '3':'Básica Secundaria','4':'Técnica o tecnología','5':'Universitario','6':'Postgrado'}) #Se editan los registros de la columna "I_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_11'] = db2017['I_11'].map({'1':'Empleado', '2':'Independiente', '3':'Informal','4':'Buscando trabajo','5':'Estudiando','6':'Oficios del hogar','7':'Rentista','8':'Jubilado / pensionado','9':'Voluntariado en actividades sociales o políticas','10':'Con situación de discapacidad que no permite trabajar','-99':'No sabe, no responde'}) #Se editan los registros de la columna "I_11", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_12_1'] = db2017['I_12_1'].map({'1':'Si', '2':'No', '-88':'No responde'}) #Se editan los registros de la columna "I_12_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_12_2'] = db2017['I_12_2'].map({'1':'Si', '2':'No', '-88':'No responde'}) #Se editan los registros de la columna "I_12_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_12_3'] = db2017['I_12_3'].map({'1':'Si', '2':'No', '-88':'No responde'}) #Se editan los registros de la columna "I_12_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_12_4'] = db2017['I_12_4'].map({'1':'Si', '2':'No', '-88':'No responde'}) #Se editan los registros de la columna "I_12_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_12_5'] = db2017['I_12_5'].map({'1':'Si', '2':'No', '-88':'No responde'}) #Se editan los registros de la columna "I_12_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_13'] = db2017['I_13'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_13", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_14'] = db2017['I_14'].map({'1':'Derechos humanos, convivencia y ciudadanía', '2':'Población étnica o afrodescendiente', '3':'Población LGTBI','4':'Víctimas del conflicto','5':'Adulto mayor','6':'Población discapacitada','7':'Ecológico o ambiental','8':'Jóvenes','9':'mujeres','10':'Expresiones juveniles urbanas y musicales','11':'Cultura, arte y patrimonio',
                                     '12':'Salud','13':'Población en situación de calle','14':'Recreación y deporte','15':'Niñez e infancia','16':'Servicios públicos','17':'Vivienda y espacio público','18':'Organizaciones religiosas que realizan acciones comunitarias','20':'Redes sociales que promueven iniciativas ciudadanas','21':'Otro'}) #Se editan los registros de la columna "I_14", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_15'] = db2017['I_15'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_15", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_16'] = db2017['I_16'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_16", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_17_1'] = db2017['I_17_1'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_17_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_17_2'] = db2017['I_17_2'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_17_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_17_3'] = db2017['I_17_3'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_17_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_17_4'] = db2017['I_17_4'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_17_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_17_5'] = db2017['I_17_5'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_17_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_1'] = db2017['I_18_1'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_2'] = db2017['I_18_2'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_3'] = db2017['I_18_3'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_4'] = db2017['I_18_4'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_5'] = db2017['I_18_5'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_6'] = db2017['I_18_6'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_7'] = db2017['I_18_7'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_8'] = db2017['I_18_8'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_9'] = db2017['I_18_9'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_10'] = db2017['I_18_10'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_11'] = db2017['I_18_11'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_11", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_12'] = db2017['I_18_12'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_12", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_13'] = db2017['I_18_13'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_13", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_18_14'] = db2017['I_18_14'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_18_14", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_19'] = db2017['I_19'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_19", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_20'] = db2017['I_20'].map({'1':'La alcaldía', '2':'El programa de presupuesto participativo', '3':'La Junta de Acción Comunal','4':'Una organización social de la comuna o corregimiento','5':'Una ONG de la ciudad','6':'Un órgano de control (Personería. Contraloría, Defensoría del Pueblo)','7':'El Concejo Municipal','-88':'Otro'}) #Se editan los registros de la columna "I_20", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_21_1'] = db2017['I_21_1'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_21_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_21_2'] = db2017['I_21_2'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_21_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_21_3'] = db2017['I_21_3'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_21_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_22'] = db2017['I_22'].map({'1':'Si', '2':'No','3':'Otro'}) #Se editan los registros de la columna "I_22", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_23'] = db2017['I_23'].map({'1':'Si', '2':'No','3':'Otro'}) #Se editan los registros de la columna "I_23", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_24'] = db2017['I_24'].map({'1':'Adecuadas', '2':'Regulares','3':'Inadecuadas','-88':'-88'}) #Se editan los registros de la columna "I_24", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_1'] = db2017['I_25_1'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_2'] = db2017['I_25_2'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_3'] = db2017['I_25_3'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_4'] = db2017['I_25_4'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_5'] = db2017['I_25_5'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_6'] = db2017['I_25_6'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_7'] = db2017['I_25_7'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_8'] = db2017['I_25_8'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_25_9'] = db2017['I_25_9'].map({'1':'Para nada dispuesto', '2':'Poco dispuesto','3':'Indiferente','4':'Algo dispuesto','5':'Totalmente dispuesto'}) #Se editan los registros de la columna "I_25_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_26_1'] = db2017['I_26_1'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_26_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_26_2'] = db2017['I_26_2'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_26_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_26_3'] = db2017['I_26_3'].map({'1':'Si', '2':'No','-88':'No responde'}) #Se editan los registros de la columna "I_26_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_27'] = db2017['I_27'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_27", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_28_1'] = db2017['I_28_1'].map({'1':'Bandas o combos delincuenciales', '2':'Grupos guerrilleros o milicias', '3':'La Policía','4':'El Ejército','5':'Reinsertados de paramilitares','6':'Reinsertados de grupos guerrilleros','7':'El gobierno municipal','8':'Otros grupos o colectivos comunitarios','9':'Algún líder social comunitario','10':'No ha sido amenazado para participar'}) #Se editan los registros de la columna "I_28_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_28_2'] = db2017['I_28_2'].map({'1':'Bandas o combos delincuenciales', '2':'Grupos guerrilleros o milicias', '3':'La Policía','4':'El Ejército','5':'Reinsertados de paramilitares','6':'Reinsertados de grupos guerrilleros','7':'El gobierno municipal','8':'Otros grupos o colectivos comunitarios','9':'Algún líder social comunitario','10':'No ha sido amenazado para participar'}) #Se editan los registros de la columna "I_28_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_29'] = db2017['I_29'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_29", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_30'] = db2017['I_30'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_30", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_31'] = db2017['I_31'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_31", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_32'] = db2017['I_32'].map({'1':'Suficiente y Clara', '2':'Incompleta o Confusa','3':'No recibió'}) #Se editan los registros de la columna "I_32", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_33'] = db2017['I_33'].map({'1':'Mejoras a nivel individual y familiar', '2':'Beneficios para el barrio y la comuna','3':'Mejoras para la ciudad y el país'}) #Se editan los registros de la columna "I_33", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_34_1'] = db2017['I_34_1'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_34_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_34_2'] = db2017['I_34_2'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_34_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_34_3'] = db2017['I_34_3'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_34_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_34_4'] = db2017['I_34_4'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_34_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_35_1'] = db2017['I_35_1'].map({'1':'Cuestiones económicas', '2':'Diferencias entre jóvenes y mayores', '3':'Diferencias entre géneros','4':'Inclusión o exclusión de un grupo social','5':'Intereses políticos','6':'Estilos de liderazgo','7':'Diferencias ideológicas','8':'No se han presentado conflictos'}) #Se editan los registros de la columna "I_35_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_35_2'] = db2017['I_35_2'].map({'1':'Cuestiones económicas', '2':'Diferencias entre jóvenes y mayores', '3':'Diferencias entre géneros','4':'Inclusión o exclusión de un grupo social','5':'Intereses políticos','6':'Estilos de liderazgo','7':'Diferencias ideológicas','8':'No se han presentado conflictos'}) #Se editan los registros de la columna "I_35_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_38'] = db2017['I_38'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_38", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_39_1'] = db2017['I_39_1'].map({'1':'Sexo', '2':'Genero', '3':'Clase social','4':'Edad','5':'Etnia','6':'Migrante/ desplazado','7':'Discapacidad física','8':'Nivel educativo','9':'Otro',}) #Se editan los registros de la columna "I_39_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_39_2'] = db2017['I_39_2'].map({'1':'Sexo', '2':'Genero', '3':'Clase social','4':'Edad','5':'Etnia','6':'Migrante/ desplazado','7':'Discapacidad física','8':'Nivel educativo','9':'Otro',}) #Se editan los registros de la columna "I_39_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_41'] = db2017['I_41'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_41", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_44'] = db2017['I_44'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_44", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_45'] = db2017['I_45'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_45", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_1'] = db2017['I_90_1'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_2'] = db2017['I_90_2'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_3'] = db2017['I_90_3'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_4'] = db2017['I_90_4'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_5'] = db2017['I_90_5'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_6'] = db2017['I_90_6'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_7'] = db2017['I_90_7'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_8'] = db2017['I_90_8'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_9'] = db2017['I_90_9'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_90_10'] = db2017['I_90_10'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_90_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_1'] = db2017['I_91_1'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_2'] = db2017['I_91_2'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_3'] = db2017['I_91_3'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_4'] = db2017['I_91_4'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_5'] = db2017['I_91_5'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_6'] = db2017['I_91_6'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_7'] = db2017['I_91_7'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_8'] = db2017['I_91_8'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_9'] = db2017['I_91_9'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_91_10'] = db2017['I_91_10'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_91_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_1'] = db2017['I_46_1'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_2'] = db2017['I_46_2'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_3'] = db2017['I_46_3'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_4'] = db2017['I_46_4'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_5'] = db2017['I_46_5'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_6'] = db2017['I_46_6'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_7'] = db2017['I_46_7'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_8'] = db2017['I_46_8'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_9'] = db2017['I_46_9'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_46_10'] = db2017['I_46_10'].map({'1':'No lo conozco', '2':'Lo conozco, pero no lo he usado','3':'Lo he usado'}) #Se editan los registros de la columna "I_46_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_47'] = db2017['I_47'].map({'1':'Mejorado', '2':'Permanecido iguales','3':'Empeorado'}) #Se editan los registros de la columna "I_47", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_49'] = db2017['I_49'].map({'1':'Si', '2':'No','3':'No Sabe No Responde'}) #Se editan los registros de la columna "I_49", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_50'] = db2017['I_50'].map({'1':'Si', '2':'No','3':'No Sabe No Responde'}) #Se editan los registros de la columna "I_50", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_51_1'] = db2017['I_51_1'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_51_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_51_2'] = db2017['I_51_2'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_51_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_51_3'] = db2017['I_51_3'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_51_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_51_4'] = db2017['I_51_4'].map({'1':'Totalmente en desacuerdo', '2':'En desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_51_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_52'] = db2017['I_52'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_52", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_54'] = db2017['I_54'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_54", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_55'] = db2017['I_55'].map({'1':'Si', '2':'No'}) #Se editan los registros de la columna "I_55", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_56'] = db2017['I_56'].map({'1':'Jóvenes', '2':'Mujeres','3':'Negritudes','4':'Indígenas','5':'Adultos mayores','-88':'Ninguno de los anteriores'}) #Se editan los registros de la columna "I_56", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_57_1'] = db2017['I_57_1'].map({'1':'Jóvenes', '2':'Mujeres','3':'Negritudes','4':'Indígenas','5':'Adultos mayores','6':'Todos tiene la misma oportunidad'}) #Se editan los registros de la columna "I_57_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_57_2'] = db2017['I_57_2'].map({'1':'Jóvenes', '2':'Mujeres','3':'Negritudes','4':'Indígenas','5':'Adultos mayores','6':'Todos tiene la misma oportunidad'}) #Se editan los registros de la columna "I_57_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_58'] = db2017['I_58'].map({'1':'Autoritarios', '2':'Democráticos','-98':'No Sabe No Responde'}) #Se editan los registros de la columna "I_58", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_1'] = db2017['I_62_1'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_2'] = db2017['I_62_2'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_3'] = db2017['I_62_3'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_4'] = db2017['I_62_4'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_5'] = db2017['I_62_5'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_6'] = db2017['I_62_6'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_7'] = db2017['I_62_7'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_8'] = db2017['I_62_8'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_9'] = db2017['I_62_9'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_10'] = db2017['I_62_10'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
db2017['I_62_11'] = db2017['I_62_11'].map({'1':'Totalmente desacuerdo', '2':'Desacuerdo','3':'Ni de acuerdo, ni en desacuerdo','4':'De acuerdo','5':'Totalmente de acuerdo'}) #Se editan los registros de la columna "I_62_11", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
# db2017 = db2017.reset_index(drop=True)
db2017 = db2017.set_index('Orden', inplace = False) #Se designa la columna Orden como índice de la base de datos
db2017 = db2017[['S_1', 'I_6', 'I_7', 'I_8', 'I_9', 'I_10',
          "I_19",	"I_21_1",	"I_21_2",	"I_21_3", "I_22",	"I_23",	"I_24",	"I_26_1",	"I_26_2","I_26_3", "I_27",	"I_28_1", "I_29",
          "I_32",	"I_33",	"I_40_1", "I_40_2", "I_40_3", "I_40_4", "I_40_5",	"I_90_1", "I_90_2","I_90_3","I_90_4","I_90_5","I_90_6","I_90_7",
          "I_90_8","I_90_9","I_90_10",
          "I_31",	"I_35_1", "I_38",	"I_51_2", "I_51_3",	"I_51_4",	"I_52",	"I_54", "I_55",	"I_48_1", "I_48_2", "I_48_3", "I_48_4", "I_48_5",
          "I_48_6","I_48_7","I_48_8","I_48_9", "I_91_1","I_91_2","I_91_3","I_91_4","I_91_5","I_91_6","I_91_7","I_91_8","I_91_9","I_91_10",
          "I_30",	"I_41",	"I_44",	"I_45","I_47"]]
db2017
#db2017['I_62_9'].unique()
# Out:
#       S_1        I_6   I_7                     I_8         I_9  \
# Orden
# 1      12   Femenino  1967  Sin pertenencia étnica     Ninguno
# 2      12  Masculino  1947  Sin pertenencia étnica     Ninguno
# 3      12   Femenino  1945        Afrodescendiente     Ninguno
# 4      12  Masculino  2002  Sin pertenencia étnica     Ninguno
# 5      12   Femenino  1952  Sin pertenencia étnica     Ninguno
# ...    ..        ...   ...                     ...         ...
# 3455    8   Femenino  1992  Sin pertenencia étnica     Ninguno
# 3456    8   Femenino  1993  Sin pertenencia étnica     Ninguno
# 3457    8   Femenino  1985  Sin pertenencia étnica  Desplazado
# 3458    8   Femenino  1985  Sin pertenencia étnica  Desplazado
# 3459    8   Femenino  1990  Sin pertenencia étnica     Ninguno
#
#                        I_10 I_19 I_21_1 I_21_2 I_21_3  ... I_91_6 I_91_7  \
# Orden                                                  ...
# ...

# %%
IPCM_I_2017 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2017/2017 Indiviudos Indicador Global Gifi.csv', header=None) #Lectura del archivo donde están contenidos los resultados de la medición del año 2017 por cada individuo (Índices y Subíndices)
IPCM_I_2017 = IPCM_I_2017.drop(range(0,10))
IPCM_I_2017 = IPCM_I_2017.rename(columns=IPCM_I_2017.iloc[0]) #Se cambia el nombre de la columna por el contenido de la primer fila 
IPCM_I_2017 = IPCM_I_2017.drop(IPCM_I_2017.index[0]) #Se elimina la primera fila para evitar duplicados
# IPCM_I_2017.Orden = IPCM_I_2017.Orden.astype(int)
# IPCM_I_2017 = IPCM_I_2017.sort_values('Orden')
IPCM_I_2017 = IPCM_I_2017[['Orden','Global C','Global P','Global E','Indice de Participación 3']] #Se filtra la base de datos con las columnas que contienen los datos necesarios
IPCM_I_2017 = IPCM_I_2017.rename(columns={'Global C':'Condiciones Territoriales', 'Global P':'Prácticas', 'Global E':'Efectos','Indice de Participación 3':'IPCM'}) #Se renombran las columnas
# IPCM_I_2017 = IPCM_I_2017.reset_index(drop=True)
IPCM_I_2017 = IPCM_I_2017.set_index('Orden', inplace = False) #Se ordena la tabla a partir de columna "Orden", de modo que concidan los indicadores con los registros de Individuos 2017
IPCM_I_2017 = IPCM_I_2017.replace(',','.', regex=True)
IPCM_I_2017 = IPCM_I_2017.astype(float)
IPCM_I_2017
# Out:
#        Condiciones Territoriales  Prácticas   Efectos  IPCM
# Orden
# 1                       0.572992   0.327955  0.297143  0.38
# 2                       0.558912   0.288059  0.150782  0.29
# 3                       0.572992   0.317118  0.365770  0.41
# 4                       0.606916   0.279306  0.365770  0.40
# 5                       0.412437   0.618331  0.150782  0.34
# ...                          ...        ...       ...   ...
# 3455                    0.386414   0.447263  0.297143  0.37
# 3456                    0.466605   0.358589  0.297143  0.37
# 3457                    0.197739   0.352001  0.297143  0.27
# 3458                    0.430291   0.384325  0.297143  0.37
# 3459                    0.386413   0.398796  0.297143  0.36
#
# [3365 rows x 4 columns]

# %%
db2017 = pd.concat([db2017,IPCM_I_2017], axis=1) #Se concatenan las tablas, dando como resultado la base de datos con los indicadores por dimensión y general (IPCM)
db2017
# Out:
#       S_1        I_6   I_7                     I_8         I_9  \
# Orden
# 1      12   Femenino  1967  Sin pertenencia étnica     Ninguno
# 2      12  Masculino  1947  Sin pertenencia étnica     Ninguno
# 3      12   Femenino  1945        Afrodescendiente     Ninguno
# 4      12  Masculino  2002  Sin pertenencia étnica     Ninguno
# 5      12   Femenino  1952  Sin pertenencia étnica     Ninguno
# ...    ..        ...   ...                     ...         ...
# 3455    8   Femenino  1992  Sin pertenencia étnica     Ninguno
# 3456    8   Femenino  1993  Sin pertenencia étnica     Ninguno
# 3457    8   Femenino  1985  Sin pertenencia étnica  Desplazado
# 3458    8   Femenino  1985  Sin pertenencia étnica  Desplazado
# 3459    8   Femenino  1990  Sin pertenencia étnica     Ninguno
#
#                        I_10 I_19 I_21_1 I_21_2 I_21_3  ... I_91_10 I_30 I_41  \
# Orden                                                  ...
# ...

# %%
db2021 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2021/participantes_final.csv',sep=';',decimal='.')
db2021['S_1'] = db2021['S_1'].str[0:2] #Se edita la columna "S_1" de modo que sólo se muestre el código de la comuna
db2021['S_1'] = db2021['S_1'].replace('-','',regex=True) #Se eliminan los guiones en la columna "S_1"
db2021 = db2021.replace(np.nan, 'Sin registro', regex=True) #Se llenan los espacios vacíos con la expresión "Sin registro" 
db2021 = db2021[['S_1', 'I_6', 'I_7', 'I_8', 'I_9', 'I_10',
          "I_19",	"I_21_1",	"I_21_2",	"I_21_3", "I_22",	"I_23",	"I_24",	"I_26_1",	"I_26_2","I_26_3", "I_27",	"I_28_1", "I_29",
          "I_32",	"I_33",	"I_40_1", "I_40_2", "I_40_3", "I_40_4", "I_40_5",	"I_90_1", "I_90_2","I_90_3","I_90_4","I_90_5","I_90_6","I_90_7",
          "I_90_8","I_90_9","I_90_10",
          "I_31",	"I_35_1", "I_38",	"I_51_2", "I_51_3",	"I_51_4",	"I_52",	"I_54", "I_55",	"I_48_1", "I_48_2", "I_48_3", "I_48_4", "I_48_5",
          "I_48_6","I_48_7","I_48_8","I_48_9", "I_91_1","I_91_2","I_91_3","I_91_4","I_91_5","I_91_6","I_91_7","I_91_8","I_91_9","I_91_10",
          "I_30",	"I_41",	"I_44",	"I_45","I_47"]]
db2021
# Out:
# C:\Users\jlope\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      S_1     I_6   I_7                                             I_8  \
# 0      4   Mujer  1954                                         Mestizo
# 1      6   Mujer  1964  No se identifica con ninguno de los anteriores
# 2      8   Mujer  1952  No se identifica con ninguno de los anteriores
# 3     15   Mujer  1967                                         Mestizo
# 4     16   Mujer  1949                                         Mestizo
# ...   ..     ...   ...                                             ...
# 4258  12  Hombre  1999  No se identifica con ninguno de los anteriores
# 4259  12  Hombre  1994                                         Mestizo
# 4260  12  Hombre  1968  No se identifica con ninguno de los anteriores
# ...

# %%
IPCM_I_2021 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2021/ipcm_ind_2021_microdatos_indice.csv',sep=';',decimal='.')
IPCM_I_2021 = IPCM_I_2021[['Subíndice Condiciones','Subíndice Prácticas','Subíndice Efectos','Indice Indiviudos']] #Se filtra la base de datos con las columnas que contienen los datos necesarios
IPCM_I_2021 = IPCM_I_2021.rename(columns={'Subíndice Condiciones':'Condiciones Territoriales', 'Subíndice Prácticas':'Prácticas', 'Subíndice Efectos':'Efectos', 'Indice Indiviudos':'IPCM'}) #Se renombran las columnas
IPCM_I_2021 = IPCM_I_2021.reset_index(drop=True)
IPCM_I_2021
# Out:
# C:\Users\jlope\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Condiciones Territoriales  Prácticas   Efectos      IPCM
# 0                      0.295925   0.328320  0.356583  0.325996
# 1                      0.709593   0.514921  0.366192  0.511469
# 2                      0.250281   0.663564  0.315747  0.374297
# 3                      0.212424   0.633268  0.345569  0.359563
# 4                      0.637970   0.521768  0.366192  0.495825
# ...                         ...        ...       ...       ...
# 4258                   0.213176   0.439429  0.305276  0.305801
# 4259                   0.194828   0.879480  0.315275  0.378027
# 4260                   0.532417   0.481450  0.311142  0.430448
# 4261                   0.548476   0.593569  0.354381  0.486818
# ...

# %%
db2021 = pd.concat([db2021,IPCM_I_2021], axis=1) #Se concatenan las tablas, dando como resultado la base de datos con los indicadores por dimensión y general (IPCM)
db2021
# Out:
#      S_1     I_6   I_7                                             I_8  \
# 0      4   Mujer  1954                                         Mestizo
# 1      6   Mujer  1964  No se identifica con ninguno de los anteriores
# 2      8   Mujer  1952  No se identifica con ninguno de los anteriores
# 3     15   Mujer  1967                                         Mestizo
# 4     16   Mujer  1949                                         Mestizo
# ...   ..     ...   ...                                             ...
# 4258  12  Hombre  1999  No se identifica con ninguno de los anteriores
# 4259  12  Hombre  1994                                         Mestizo
# 4260  12  Hombre  1968  No se identifica con ninguno de los anteriores
# 4261  12  Hombre  1998  No se identifica con ninguno de los anteriores
# 4262  12  Hombre  1997  No se identifica con ninguno de los anteriores
#
#                                              I_9                   I_10 I_19  \
# ...

# %%
dbfinal = pd.concat([db2019,db2017,db2021]) #Se concatenan las tablas que contienen los Individuos 2019 y 2017, quedando así la base de datos general con los datos consolidados de Individuos que participan
dbfinal = dbfinal.reset_index(drop=True) #Se reinicia el índice de la tabla
dbfinal['I_7'] = dbfinal['I_7'].replace(np.nan, 9999, regex=True) #Se rellenan los datos vacíos de la columna "I_7" con la sentencia "9999"
dbfinal['I_8'] = dbfinal['I_8'].replace(np.nan, 'Sin registro', regex=True) #Se rellenan los datos vacíos de la columna "I_8" con la sentencia "Sin registro"
dbfinal['I_24'] = dbfinal['I_24'].replace(-88, 'Sin registro', regex=True) #Se reemplazan los datos nulos (-88) de la columna "I_24" por la sentencia "Sin registro"
dbfinal['I_35_1'] = dbfinal['I_35_1'].replace(np.nan, 'Sin registro', regex=True) #Se rellenan los datos vacíos de la columna "I_35_1" con la sentencia "Sin registro"
dbfinal['I_47'] = dbfinal['I_47'].replace(np.nan, 'Sin registro', regex=True) #Se rellenan los datos vacíos de la columna "I_47" con la sentencia "Sin registro"
dbfinal = dbfinal.replace('Sí','Si')
dbfinal['I_24'] = dbfinal['I_24'].replace('-88','Sin registro')
dbfinal['I_27'] = dbfinal['I_27'].replace('No convoca a reuniones','No')
dbfinal['I_28_1'] = dbfinal['I_28_1'].replace('No ha sido amenazado para participar','No')
dbfinal['I_28_1'] = np.where((dbfinal.I_28_1 != 'No'), 'Si', dbfinal.I_28_1)
dbfinal['I_33'] = dbfinal['I_33'].replace('Beneficios para el barrio y la comuna','Beneficios para el barrio y la comuna, o para la vereda y el corregimiento')
dbfinal['I_35_1'] = dbfinal['I_35_1'].replace('No','No se han presentado conflictos')
dbfinal['I_51_2'] = dbfinal['I_51_2'].replace('Desacuerdo','En desacuerdo')
dbfinal['I_51_3'] = dbfinal['I_51_3'].replace('Desacuerdo','En desacuerdo')
dbfinal['I_51_4'] = dbfinal['I_51_4'].replace('Desacuerdo','En desacuerdo')
dbfinal['I_44'] = dbfinal['I_44'].replace(['Sí, medio', 'Sí, bajo', 'Sí, alto'],'Si')
dbfinal['I_47'] = dbfinal['I_47'].replace('Permanecido iguales','Permanecen iguales')
# dbfinal = dbfinal.dropna() #Se eliminan los registros vacíos que queden

dbfinal.to_csv('BDIndividuosTotal.csv', index=False) #Se exporta el archivo en formato .csv
dbfinal.to_excel('BDIndividuosTotal.xlsx', index=False) #Se exporta el archivo en formato .xlsx
dbfinal
# Out:
#       S_1        I_6   I_7                                             I_8  \
# 0       1   Femenino  1985                          Sin pertenencia étnica
# 1       1  Masculino  1953                          Sin pertenencia étnica
# 2       1   Femenino  1970                          Sin pertenencia étnica
# 3       1   Femenino  1989                          Sin pertenencia étnica
# 4       1   Femenino  1953                                         Mestizo
# ...    ..        ...   ...                                             ...
# 11356  12     Hombre  1999  No se identifica con ninguno de los anteriores
# 11357  12     Hombre  1994                                         Mestizo
# 11358  12     Hombre  1968  No se identifica con ninguno de los anteriores
# 11359  12     Hombre  1998  No se identifica con ninguno de los anteriores
# 11360  12     Hombre  1997  No se identifica con ninguno de los anteriores
#
# ...

# %%
bd2019 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2019/dataPublica_organizaciones.csv') #Lectura del archivo que contiene los datos de Organizaciones sociales del año 2019
bd2019 = bd2019.rename(columns=bd2019.iloc[0]) #Se cambia el nombre de las columnas a partir de la primera fila
bd2019 = bd2019.drop(bd2019.index[0])#Se elimina la primera fila para evitar duplicado con el nombre de la columna
bd2019 = bd2019.drop(columns = ['Date.Collected', 'Date.Sent', 'Duration.(seconds)', 'User', 'Latitude', 'Longitude', 'Comuna', 'X5', 'S_1', 'O_2', 'O_2_1']) #Se eliminan las columnas que no aportan en la medición del IPCM
bd2019 = bd2019.rename(columns={'CodComuna':'S_1'}) #Se cambia el nombre de la columna "CodComuna" por "S_1"
bd2019.insert(0, "Edicion", 2019, allow_duplicates=False) #Se agrega la columna Edición, y se le otorga a todos los registros el valor de "2019"
bd2019['O_10_1'] = bd2019['O_10_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_10_2'] = bd2019['O_10_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_10_3'] = bd2019['O_10_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_10_4'] = bd2019['O_10_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_10_5'] = bd2019['O_10_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_10_6'] = bd2019['O_10_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_10_7'] = bd2019['O_10_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_10_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_1'] = bd2019['O_11_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_2'] = bd2019['O_11_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_3'] = bd2019['O_11_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_4'] = bd2019['O_11_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_5'] = bd2019['O_11_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_6'] = bd2019['O_11_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_7'] = bd2019['O_11_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_8'] = bd2019['O_11_8'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_11_9'] = bd2019['O_11_9'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_11_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_17_1'] = bd2019['O_17_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_17_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_17_2'] = bd2019['O_17_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_17_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_17_3'] = bd2019['O_17_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_17_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_17_4'] = bd2019['O_17_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_17_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_17_5'] = bd2019['O_17_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_17_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_17_6'] = bd2019['O_17_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_17_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_18'] = bd2019['O_18'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_18", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_1'] = bd2019['O_19_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_2'] = bd2019['O_19_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_3'] = bd2019['O_19_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_4'] = bd2019['O_19_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_5'] = bd2019['O_19_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_6'] = bd2019['O_19_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_7'] = bd2019['O_19_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_8'] = bd2019['O_19_8'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_9'] = bd2019['O_19_9'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_19_10'] = bd2019['O_19_10'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_19_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_1'] = bd2019['O_20_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_2'] = bd2019['O_20_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_3'] = bd2019['O_20_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_4'] = bd2019['O_20_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_5'] = bd2019['O_20_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_6'] = bd2019['O_20_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_7'] = bd2019['O_20_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_8'] = bd2019['O_20_8'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_20_9'] = bd2019['O_20_9'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_20_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_27'] = bd2019['O_27'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_27", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_1'] = bd2019['O_28_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_2'] = bd2019['O_28_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_3'] = bd2019['O_28_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_4'] = bd2019['O_28_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_5'] = bd2019['O_28_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales. 
bd2019['O_28_6'] = bd2019['O_28_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_7'] = bd2019['O_28_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_8'] = bd2019['O_28_8'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_28_9'] = bd2019['O_28_9'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_28_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_37_1'] = bd2019['O_37_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_37_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_37_2'] = bd2019['O_37_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_37_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_37_3'] = bd2019['O_37_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_37_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_37_4'] = bd2019['O_37_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_37_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_37_5'] = bd2019['O_37_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_37_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_1'] = bd2019['O_38_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_2'] = bd2019['O_38_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_3'] = bd2019['O_38_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_4'] = bd2019['O_38_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_5'] = bd2019['O_38_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_6'] = bd2019['O_38_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_7'] = bd2019['O_38_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_8'] = bd2019['O_38_8'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_38_9'] = bd2019['O_38_9'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_38_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_57'] = bd2019['O_57'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_57", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_0'] = bd2019['O_66_0'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_0", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_1'] = bd2019['O_66_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_2'] = bd2019['O_66_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_3'] = bd2019['O_66_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_4'] = bd2019['O_66_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_5'] = bd2019['O_66_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_6'] = bd2019['O_66_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_66_7'] = bd2019['O_66_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_66_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_69'] = bd2019['O_69'].map({'SI':'Si', 'NO':'No','Más o menos':'Más o menos','No acude a ejercicios de rendición de cuentas':'No acude a ejercicios de rendición de cuentas'}) #Se editan los registros de la columna "O_69", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_70_1'] = bd2019['O_70_1'].map({'1':'De fácil acceso', '0':np.nan}) #Se editan los registros de la columna "O_70_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_70_2'] = bd2019['O_70_2'].map({'1':'Clara y comprensible', '0':np.nan}) #Se editan los registros de la columna "O_70_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_70_3'] = bd2019['O_70_3'].map({'1':'Amplia y suficiente', '0':np.nan}) #Se editan los registros de la columna "O_70_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_70_4'] = bd2019['O_70_4'].map({'1':'De utilidad para el trabajo en la comuna', '0':np.nan}) #Se editan los registros de la columna "O_70_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_70_5'] = bd2019['O_70_5'].map({'1':'No se publica información', '0':np.nan}) #Se editan los registros de la columna "O_70_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_70_6'] = bd2019['O_70_6'].map({'1':'No consulta', '0':np.nan}) #Se editan los registros de la columna "O_70_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_71_1'] = bd2019['O_71_1'].map({'1':'De fácil acceso', '0':np.nan}) #Se editan los registros de la columna "O_71_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_71_2'] = bd2019['O_71_2'].map({'1':'Clara y comprensible', '0':np.nan}) #Se editan los registros de la columna "O_71_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_71_3'] = bd2019['O_71_3'].map({'1':'Amplia y suficiente', '0':np.nan}) #Se editan los registros de la columna "O_71_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_71_4'] = bd2019['O_71_4'].map({'1':'De utilidad para el trabajo en la comuna', '0':np.nan}) #Se editan los registros de la columna "O_71_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_71_5'] = bd2019['O_71_5'].map({'1':'No se publica información', '0':np.nan}) #Se editan los registros de la columna "O_71_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_71_6'] = bd2019['O_71_6'].map({'1':'No consulta', '0':np.nan}) #Se editan los registros de la columna "O_71_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_1'] = bd2019['O_72_1'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_2'] = bd2019['O_72_2'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_3'] = bd2019['O_72_3'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_4'] = bd2019['O_72_4'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_5'] = bd2019['O_72_5'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_6'] = bd2019['O_72_6'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_7'] = bd2019['O_72_7'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_8'] = bd2019['O_72_8'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_9'] = bd2019['O_72_9'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_72_7c'] = bd2019['O_72_7c'].map({'1':'Si', '0':'No'}) #Se editan los registros de la columna "O_72_7c", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019['O_89'] = bd2019['O_89'].map({'Yes':'Si', 'No':'No'}) #Se editan los registros de la columna "O_89", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2019 = bd2019.reset_index(drop=True)
bd2019 = bd2019[["Edicion","S_1","O_88","O_89",
                 "O_12","O_13","O_22","O_67","O_68","O_8","O_19_1","O_19_2","O_19_3","O_19_4","O_19_5","O_19_6","O_19_7","O_19_8","O_19_9", 
                 "O_20_1","O_20_2","O_20_3","O_20_4","O_20_5","O_20_6","O_20_7","O_20_8","O_70_1","O_70_2","O_70_3","O_70_4","O_70_5","O_70_6",
                 "O_71_1","O_71_2","O_71_3","O_71_4","O_71_5","O_71_6",	"O_72_1","O_72_2","O_72_3","O_72_4","O_72_5","O_72_6","O_72_7","O_72_8","O_72_9",
                 "O_24","O_48","O_52","O_54","O_58","O_59","O_90","O_28_1","O_28_2","O_28_3","O_28_4","O_28_5","O_28_6","O_28_7","O_28_8",
                 "O_37_1","O_37_2","O_37_3","O_37_4","O_37_5","O_38_1","O_38_2","O_38_3","O_38_4","O_38_5","O_38_6","O_38_7","O_38_8","O_38_9",
                 "O_66_1","O_66_2","O_66_3","O_66_4","O_66_5","O_66_6","O_66_7","O_81_1","O_81_2","O_81_3","O_81_4","O_81_5","O_81_6","O_81_7",
                 "O_82_1","O_82_2","O_82_3","O_82_4","O_82_5","O_82_6","O_82_7",
                 "O_40","O_41","O_45","O_49","O_55","O_61_1","O_61_2","O_61_3","O_61_4","O_61_5","O_62_1","O_62_2","O_62_3","O_62_4","O_62_5","O_62_6"]]

bd2019['O_70'] = bd2019[bd2019.columns[27:33]].apply(    #Con este código, se unifica en una columna los datos de la O_70_1 a O_70_6.
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1)
bd2019['O_70'] = bd2019['O_70'].str.split(',').str[0]

bd2019['O_71'] = bd2019[bd2019.columns[33:39]].apply(    #Con este código, se unifica en una columna los datos de la O_71_1 a O_71_6.
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1)

bd2019['O_71'] = bd2019['O_71'].str.split(',').str[0]
bd2019 = bd2019.drop(columns = ["O_70_1","O_70_2","O_70_3","O_70_4","O_70_5","O_70_6","O_71_1","O_71_2","O_71_3","O_71_4","O_71_5","O_71_6"]) #Se eliminan las columnas que se unificaron previamente

bd2019
# np.array(bd2019.columns)
bd2019['O_71'].unique()
# Out:
# array(['De fácil acceso', 'No consulta', 'Amplia y suficiente',
#        'Clara y comprensible', 'De utilidad para el trabajo en la comuna',
#        'No se publica información'], dtype=object)

# %%
IPCM_O_2019 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2019/Organizaciones Indicador Global Gifi.csv', header=None) #Lectura del archivo donde están contenidos los resultados de la medición del año 2017 por cada organización (Índices y Subíndices)
IPCM_O_2019 = IPCM_O_2019.drop(range(0,10))
IPCM_O_2019 = IPCM_O_2019.rename(columns=IPCM_O_2019.iloc[0]) #Se cambia el nombre de las columnas a partir de la primera fila
IPCM_O_2019 = IPCM_O_2019.drop(IPCM_O_2019.index[0]) #Se elimina la primera fila para evitar duplicados
# IPCM_O_2019.Orden = IPCM_O_2019.Orden.astype(int)
# IPCM_O_2019 = IPCM_O_2019.sort_values('Orden')
IPCM_O_2019 = IPCM_O_2019[['Orden','Global C','Global P','Global E','Indice de Participación 3']] #Se filtra la base de datos para que muestre sólo los datos necesarios
IPCM_O_2019 = IPCM_O_2019.rename(columns={'Global C':'Condiciones Territoriales', 'Global P':'Prácticas', 'Global E':'Efectos','Indice de Participación 3':'IPCM'}) #Se renombran las columnas de acuerdo al nombre de la dimensión correspondiente
IPCM_O_2019 = IPCM_O_2019.set_index('Orden', inplace = False) #Se convierte la columna Orden en el índice de la tabla
IPCM_O_2019 = IPCM_O_2019.reset_index(drop=True) #Se reinicia el índice
IPCM_O_2019 = IPCM_O_2019.replace(',','.', regex=True)
IPCM_O_2019 = IPCM_O_2019.astype(float)
IPCM_O_2019
# Out:
#       Condiciones Territoriales  Prácticas   Efectos  IPCM
# 0                      0.824500   0.772059  0.776281  0.79
# 1                      0.734871   0.803540  0.720852  0.75
# 2                      0.547074   0.374272  0.230637  0.36
# 3                      0.763295   0.638824  0.560334  0.65
# 4                      0.629710   0.772367  0.639018  0.68
# ...                         ...        ...       ...   ...
# 1107                   0.515327   0.508011  0.208340  0.38
# 1108                   0.811247   0.782072  0.682605  0.76
# 1109                   0.621610   0.674550  0.639639  0.64
# 1110                   0.738242   0.665845  0.671562  0.69
# 1111                   0.598278   0.714612  0.308704  0.51
#
# [1112 rows x 4 columns]

# %%
bd2019 = pd.concat([bd2019,IPCM_O_2019], axis=1) #Se concatenan las bases de datos de modo que se le añade los subíndices por dimensión y el IPCM a los datos de organizaciones
bd2019
# Out:
#       Edicion S_1    O_88 O_89 O_12 O_13  O_22           O_67           O_68  \
# 0        2019   1  Hombre   Si   Si   No   300    No consulta    No consulta
# 1        2019   1   Mujer   No   Si   Si    50    No consulta    No consulta
# 2        2019   1  Hombre   No   Si   Si  3000  Algunas veces   Casi siempre
# 3        2019   1   Mujer   No   Si   Si    30    No consulta    No consulta
# 4        2019   1   Mujer   Si   Si   Si    12  Algunas veces  Algunas veces
# ...       ...  ..     ...  ...  ...  ...   ...            ...            ...
# 1107     2019  90   Mujer   Si   Si   Si   786   Casi siempre   Casi siempre
# 1108     2019  90   Mujer   Si   Si   Si    50    No consulta    No consulta
# 1109     2019  90  Hombre   Si   Si   Si    47  Algunas veces  Algunas veces
# 1110     2019  90   Mujer   Si   Si   Si    30    No consulta    No consulta
# 1111     2019  90  Hombre   Si   Si   No    90  Algunas veces  Algunas veces
#
# ...

# %%
bd2017 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2017/BD_Organizaciones20180415.csv') #Lectura del archivo con los datos de organizaciones sociales del año 2017
bd2017 = bd2017.drop(bd2017[bd2017['O_4']=='-55'].index) #Se eliminan los datos nulos de la columna "0_4"
bd2017 = bd2017.drop(columns = ['form','S_00','O_2','O_2_1','O_12c','O_13c','O_14','O_15','O_19','O_19_11','O_29','O_33_1','O_33_2','O_35','O_37_6','O_39','O_42','O_42_1','O_42_2','O_42_3','O_42_4','O_43_1','O_43_2','O_43_3','O_43_4','O_43_5','O_43_6','O_43_7','O_43_8','O_43_9','O_44_1','O_56','O_57c','O_63','O_66_7c','O_73','O_86','O_88c']) #Se eliminan las columnas que no son importantes para el IPCM o que se descartaron para la medición de 2019
bd2017.insert(0, "Edicion", 2017, allow_duplicates=False) #Se añade la columna "Edición" y se le otorga el registro 2017
bd2017['O_8'] = bd2017['O_8'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017 = bd2017.rename(columns={'O_10':'O_10_7', 'O_11':'O_11_9', 'O_17':'O_17_6', 'O_20':'O_20_9', 'O_28':'O_28_9'}) #Se renombran las columnas de modo que coincida con los datos de 2019
bd2017['O_10_1'] = bd2017['O_10_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_10_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_10_2'] = bd2017['O_10_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_10_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_10_3'] = bd2017['O_10_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_10_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_10_4'] = bd2017['O_10_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_10_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_10_5'] = bd2017['O_10_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_10_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_10_6'] = bd2017['O_10_6'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_10_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_10_7'] = bd2017['O_10_7'].map({2:'Si', 1:'No'}) #Se editan los registros de la columna "O_10_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_1'] = bd2017['O_11_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_2'] = bd2017['O_11_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_3'] = bd2017['O_11_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_4'] = bd2017['O_11_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_5'] = bd2017['O_11_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_6'] = bd2017['O_11_6'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_7'] = bd2017['O_11_7'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_8'] = bd2017['O_11_8'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_11_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_11_9'] = bd2017['O_11_9'].map({2:'Si', 1:'No'}) #Se editan los registros de la columna "O_11_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_12'] = bd2017['O_12'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_12", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_13'] = bd2017['O_13'].map({1:'Si', 2:'No', 3:'Otro'}) #Se editan los registros de la columna "O_13", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_1'] = bd2017['O_16_1'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_2'] = bd2017['O_16_2'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_3'] = bd2017['O_16_3'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_4'] = bd2017['O_16_4'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_5'] = bd2017['O_16_5'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_6'] = bd2017['O_16_6'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_7'] = bd2017['O_16_7'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_8'] = bd2017['O_16_8'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_16_9'] = bd2017['O_16_9'].map({1:'1 Para nada dispuesta', 2:'2 Poco dispuesta', 3:'3 Es indiferente', 4:'4 Algo dispuesta', 5:'5 Totalmente dispuesta'}) #Se editan los registros de la columna "O_16_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_17_1'] = bd2017['O_17_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_17_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_17_2'] = bd2017['O_17_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_17_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_17_3'] = bd2017['O_17_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_17_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_17_4'] = bd2017['O_17_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_17_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_17_5'] = bd2017['O_17_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_17_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_17_6'] = bd2017['O_17_6'].map({2:'Si', 1:'No'}) #Se editan los registros de la columna "O_17_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_18'] = bd2017['O_18'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_18", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_1'] = bd2017['O_19_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_2'] = bd2017['O_19_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_3'] = bd2017['O_19_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_4'] = bd2017['O_19_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_5'] = bd2017['O_19_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_6'] = bd2017['O_19_6'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_7'] = bd2017['O_19_7'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_8'] = bd2017['O_19_8'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_9'] = bd2017['O_19_9'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_19_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_19_10'] = bd2017['O_19_10'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_19_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_1'] = bd2017['O_20_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_2'] = bd2017['O_20_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_3'] = bd2017['O_20_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_4'] = bd2017['O_20_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_5'] = bd2017['O_20_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_6'] = bd2017['O_20_6'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_7'] = bd2017['O_20_7'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_20_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_20_9'] = bd2017['O_20_9'].map({2:'Si', 1:'No'}) #Se editan los registros de la columna "O_20_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_25_1'] = bd2017['O_25_1'].map({1:'Totalmente en desacuerdo', 2:'En desacuerdo', 3:'Ni de acuerdo, ni en desacuerdo', 4:'De acuerdo', 5:'Totalmente de acuerdo'}) #Se editan los registros de la columna "O_25_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_25_2'] = bd2017['O_25_2'].map({1:'Totalmente en desacuerdo', 2:'En desacuerdo', 3:'Ni de acuerdo, ni en desacuerdo', 4:'De acuerdo', 5:'Totalmente de acuerdo'}) #Se editan los registros de la columna "O_25_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_25_3'] = bd2017['O_25_3'].map({1:'Totalmente en desacuerdo', 2:'En desacuerdo', 3:'Ni de acuerdo, ni en desacuerdo', 4:'De acuerdo', 5:'Totalmente de acuerdo'}) #Se editan los registros de la columna "O_25_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_25_4'] = bd2017['O_25_4'].map({1:'Totalmente en desacuerdo', 2:'En desacuerdo', 3:'Ni de acuerdo, ni en desacuerdo', 4:'De acuerdo', 5:'Totalmente de acuerdo'}) #Se editan los registros de la columna "O_25_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_26_1'] = bd2017['O_26_1'].map({1:'Cuestiones económicas', 2:'Diferencias entre jóvenes y mayores', 3:'Diferencias entre géneros', 4:'Inclusión o exclusión de un grupo social', 5:'Intereses políticos', 6: 'Estilos de liderazgo', 7:'Diferencias ideológicas', 8:'No se han presentado conflictos [SI ELIGE ESTA OPCIÓN NO ELIJA LAS OPCIONES RESTANTES]'}) #Se editan los registros de la columna "O_26_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_26_2'] = bd2017['O_26_2'].map({1:'Cuestiones económicas', 2:'Diferencias entre jóvenes y mayores', 3:'Diferencias entre géneros', 4:'Inclusión o exclusión de un grupo social', 5:'Intereses políticos', 6: 'Estilos de liderazgo', 7:'Diferencias ideológicas', 8:'No se han presentado conflictos [SI ELIGE ESTA OPCIÓN NO ELIJA LAS OPCIONES RESTANTES]'}) #Se editan los registros de la columna "O_26_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_27'] = bd2017['O_27'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_27", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_1'] = bd2017['O_28_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_2'] = bd2017['O_28_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_3'] = bd2017['O_28_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_4'] = bd2017['O_28_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_5'] = bd2017['O_28_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_6'] = bd2017['O_28_6'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_7'] = bd2017['O_28_7'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_28_9'] = bd2017['O_28_9'].map({2:'Si', 1:'No', -88:'No responde'}) #Se editan los registros de la columna "O_28_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_34_1'] = bd2017['O_34_1'].map({1:'Organizaciones o colectivos de su propia comuna o corregimiento', 2:'Organizaciones o colectivos de otras comunas o de la ciudad', 3:'El gobierno nacional o departamental', 4:'El gobierno municipal', 5:'Entes internacionales'}) #Se editan los registros de la columna "O_34_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_34_2'] = bd2017['O_34_2'].map({1:'Organizaciones o colectivos de su propia comuna o corregimiento', 2:'Organizaciones o colectivos de otras comunas o de la ciudad', 3:'El gobierno nacional o departamental', 4:'El gobierno municipal', 5:'Entes internacionales'}) #Se editan los registros de la columna "O_34_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_36_1'] = bd2017['O_36_1'].map({1:'Grupos indígenas', 2:'Afrodescendientes', 3:'Las mujeres', 4:'LGTBI', 5:'Víctimas del conflicto', 6:'Desmovilizados', 7:'Personas con discapacidad', 8:'Grupos etarios', 9:'Grupos de derechos humanos', 10:'Grupos de desarrollo local', 11:'Grupos de desarrollo empresarial', 12:'Grupos ambientales', 13:'Grupos de control social', 14:'Otro', -88:'Ninguno [ELIJA ESTA RESPUESTA SI NO MARCA NINGUNA DE LAS OPCIONES]'}) #Se editan los registros de la columna "O_36_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_36_2'] = bd2017['O_36_2'].map({1:'Grupos indígenas', 2:'Afrodescendientes', 3:'Las mujeres', 4:'LGTBI', 5:'Víctimas del conflicto', 6:'Desmovilizados', 7:'Personas con discapacidad', 8:'Grupos etarios', 9:'Grupos de derechos humanos', 10:'Grupos de desarrollo local', 11:'Grupos de desarrollo empresarial', 12:'Grupos ambientales', 13:'Grupos de control social', 14:'Otro', -88:'Ninguno [ELIJA ESTA RESPUESTA SI NO MARCA NINGUNA DE LAS OPCIONES]'}) #Se editan los registros de la columna "O_36_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_36_3'] = bd2017['O_36_3'].map({1:'Grupos indígenas', 2:'Afrodescendientes', 3:'Las mujeres', 4:'LGTBI', 5:'Víctimas del conflicto', 6:'Desmovilizados', 7:'Personas con discapacidad', 8:'Grupos etarios', 9:'Grupos de derechos humanos', 10:'Grupos de desarrollo local', 11:'Grupos de desarrollo empresarial', 12:'Grupos ambientales', 13:'Grupos de control social', 14:'Otro', -88:'Ninguno [ELIJA ESTA RESPUESTA SI NO MARCA NINGUNA DE LAS OPCIONES]'}) #Se editan los registros de la columna "O_36_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_37_1'] = bd2017['O_37_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_37_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_37_2'] = bd2017['O_37_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_37_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_37_3'] = bd2017['O_37_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_37_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_37_4'] = bd2017['O_37_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_37_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_37_5'] = bd2017['O_37_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_37_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_1'] = bd2017['O_38_1'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_2'] = bd2017['O_38_2'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_3'] = bd2017['O_38_3'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_4'] = bd2017['O_38_4'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_5'] = bd2017['O_38_5'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_6'] = bd2017['O_38_6'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_7'] = bd2017['O_38_7'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_8'] = bd2017['O_38_8'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_38_9'] = bd2017['O_38_9'].map({1:'Si', 2:'No', -88:'No responde'}) #Se editan los registros de la columna "O_38_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_40'] = bd2017['O_40'].map({1:'Si, alto', 2:'Si, medio', 3:'Si, bajo', 4:'No'}) #Se editan los registros de la columna "O_40", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_41'] = bd2017['O_41'].map({1:'Positiva', 2:'Negativa'}) #Se editan los registros de la columna "O_41", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_44_2'] = bd2017['O_44_2'].map({1:'No los hemos usado', 2:'Ninguna incidencia o efectividad', 3:'Poca incidencia o efectividad', 4:'Bastante incidencia o efectividad'}) #Se editan los registros de la columna "O_44_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_44_3'] = bd2017['O_44_3'].map({1:'No los hemos usado', 2:'Ninguna incidencia o efectividad', 3:'Poca incidencia o efectividad', 4:'Bastante incidencia o efectividad'}) #Se editan los registros de la columna "O_44_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_44_4'] = bd2017['O_44_4'].map({1:'No los hemos usado', 2:'Ninguna incidencia o efectividad', 3:'Poca incidencia o efectividad', 4:'Bastante incidencia o efectividad'}) #Se editan los registros de la columna "O_44_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_44_5'] = bd2017['O_44_5'].map({1:'No los hemos usado', 2:'Ninguna incidencia o efectividad', 3:'Poca incidencia o efectividad', 4:'Bastante incidencia o efectividad'}) #Se editan los registros de la columna "O_44_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_44_6'] = bd2017['O_44_6'].map({1:'No los hemos usado', 2:'Ninguna incidencia o efectividad', 3:'Poca incidencia o efectividad', 4:'Bastante incidencia o efectividad'}) #Se editan los registros de la columna "O_44_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_44_7'] = bd2017['O_44_7'].map({1:'No los hemos usado', 2:'Ninguna incidencia o efectividad', 3:'Poca incidencia o efectividad', 4:'Bastante incidencia o efectividad'}) #Se editan los registros de la columna "O_44_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_45'] = bd2017['O_45'].map({1:'Mejorado', 2:'Permanecen igual', 3:'Empeorado', 4:'No sabe, no responde', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_45", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_48'] = bd2017['O_48'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_48", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_54'] = bd2017['O_54'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_54", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_57'] = bd2017['O_57'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_57", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_58'] = bd2017['O_58'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_58", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_59'] = bd2017['O_59'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_59", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_1'] = bd2017['O_60_1'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_2'] = bd2017['O_60_2'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_3'] = bd2017['O_60_3'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_4'] = bd2017['O_60_4'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_5'] = bd2017['O_60_5'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_6'] = bd2017['O_60_6'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_7'] = bd2017['O_60_7'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_8'] = bd2017['O_60_8'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_8", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_9'] = bd2017['O_60_9'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_9", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_60_10'] = bd2017['O_60_10'].map({1:'Desconfía completamente', 2:'Desconfía', 3:'Neutral', 4:'Confía', 5:'Confía totalmente', 6:'No lo conoce'}) #Se editan los registros de la columna "O_60_10", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_61_1'] = bd2017['O_61_1'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_61_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_61_2'] = bd2017['O_61_2'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_61_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_61_3'] = bd2017['O_61_3'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_61_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_61_4'] = bd2017['O_61_4'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_61_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_61_5'] = bd2017['O_61_5'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_61_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_62_1'] = bd2017['O_62_1'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_62_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_62_2'] = bd2017['O_62_2'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_62_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_62_3'] = bd2017['O_62_3'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_62_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_62_4'] = bd2017['O_62_4'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_62_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_62_5'] = bd2017['O_62_5'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_62_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_62_6'] = bd2017['O_62_6'].map({1:'Totalmente inequitativo', 2:'Inequitativo', 3:'Neutral', 4:'Equitativo', 5:'Totalmente equitativo', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_62_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_64'] = bd2017['O_64'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_64", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_65'] = bd2017['O_65'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_65", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_0'] = bd2017['O_66_0'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_0", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_1'] = bd2017['O_66_1'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_2'] = bd2017['O_66_2'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_3'] = bd2017['O_66_3'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_4'] = bd2017['O_66_4'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_5'] = bd2017['O_66_5'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_6'] = bd2017['O_66_6'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_66_7'] = bd2017['O_66_7'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_61_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_67'] = bd2017['O_67'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'No consulta', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_67", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_68'] = bd2017['O_68'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'No consulta', -98:'No sabe, no responde'}) #Se editan los registros de la columna "O_68", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_69'] = bd2017['O_69'].map({1:'Si', 2:'No', 3:'Más o menos'}) #Se editan los registros de la columna "O_69", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_70_1'] = bd2017['O_70_1'].map({1:'De fácil acceso', 0:np.nan}) #Se editan los registros de la columna "O_70_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_70_2'] = bd2017['O_70_2'].map({1:'Clara y comprensible', 0:np.nan}) #Se editan los registros de la columna "O_70_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_70_3'] = bd2017['O_70_3'].map({1:'Amplia y suficiente', 0:np.nan}) #Se editan los registros de la columna "O_70_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_70_4'] = bd2017['O_70_4'].map({1:'De utilidad para el trabajo en la comuna', 0:np.nan}) #Se editan los registros de la columna "O_70_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_71_1'] = bd2017['O_71_1'].map({1:'De fácil acceso', 0:np.nan}) #Se editan los registros de la columna "O_71_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_71_2'] = bd2017['O_71_2'].map({1:'Clara y comprensible', 0:np.nan}) #Se editan los registros de la columna "O_71_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_71_3'] = bd2017['O_71_3'].map({1:'Amplia y suficiente', 0:np.nan}) #Se editan los registros de la columna "O_71_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_71_4'] = bd2017['O_71_4'].map({1:'De utilidad para el trabajo en la comuna', 0:np.nan}) #Se editan los registros de la columna "O_71_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_1'] = bd2017['O_72_1'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_2'] = bd2017['O_72_2'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_3'] = bd2017['O_72_3'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_4'] = bd2017['O_72_4'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_5'] = bd2017['O_72_5'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_6'] = bd2017['O_72_6'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_72_7'] = bd2017['O_72_7'].map({1:'Si', 2:'No'}) #Se editan los registros de la columna "O_72_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_74'] = bd2017['O_74'].map({1:'Muy satisfecho (sensación percibida que excede a las expectativas)', 2:'Satisfecho (sensación percibida coincide con las expectativos)', 3:'Insatisfecho (sensación percibida no alcanza las expectativas)', 4:'No ha realizado derechos de petición'}) #Se editan los registros de la columna "O_74", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_75'] = bd2017['O_75'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'Nunca'}) #Se editan los registros de la columna "O_75", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_76'] = bd2017['O_76'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'Nunca'}) #Se editan los registros de la columna "O_76", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_77'] = bd2017['O_77'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'Nunca'}) #Se editan los registros de la columna "O_77", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_78'] = bd2017['O_78'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'Nunca'}) #Se editan los registros de la columna "O_78", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_79'] = bd2017['O_79'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'Nunca'}) #Se editan los registros de la columna "O_79", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_80'] = bd2017['O_80'].map({1:'Siempre', 2:'Casi siempre', 3:'Algunas veces', 4:'Muy pocas veces', 5:'Nunca'}) #Se editan los registros de la columna "O_80", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_1'] = bd2017['O_81_1'].map({1:'Muy autoritario', 2:'Autoritario', 3:'Democrático', 4:'Muy democrático'}) #Se editan los registros de la columna "O_81_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_2'] = bd2017['O_81_2'].map({1:'Muy manipulador', 2:'Manipulador', 3:'Condescendiente', 4:'Muy condescendiente'}) #Se editan los registros de la columna "O_81_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_3'] = bd2017['O_81_3'].map({1:'Muy excluyente', 2:'Excluyente', 3:'Inclusivo', 4:'Muy inclusivo'}) #Se editan los registros de la columna "O_81_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_4'] = bd2017['O_81_4'].map({1:'Muy dictatorial', 2:'Dictatorial', 3:'Consultivo', 4:'Muy consultivo'}) #Se editan los registros de la columna "O_81_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_5'] = bd2017['O_81_5'].map({1:'Muy pasivo', 2:'Pasivo', 3:'Proactivo', 4:'Muy proactivo'}) #Se editan los registros de la columna "O_81_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_6'] = bd2017['O_81_6'].map({1:'Muy apático', 2:'Apático', 3:'Cooperativo', 4:'Muy cooperativo'}) #Se editan los registros de la columna "O_81_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_81_7'] = bd2017['O_81_7'].map({1:'Muy autosuficiente', 2:'Autosuficiente', 3:'Delegativo', 4:'Muy delegativo'}) #Se editan los registros de la columna "O_81_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_1'] = bd2017['O_82_1'].map({1:'Muy autoritario', 2:'Autoritario', 3:'Democrático', 4:'Muy democrático'}) #Se editan los registros de la columna "O_82_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_2'] = bd2017['O_82_2'].map({1:'Muy manipulador', 2:'Manipulador', 3:'Condescendiente', 4:'Muy condescendiente'}) #Se editan los registros de la columna "O_82_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_3'] = bd2017['O_82_3'].map({1:'Muy excluyente', 2:'Excluyente', 3:'Inclusivo', 4:'Muy inclusivo'}) #Se editan los registros de la columna "O_82_3", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_4'] = bd2017['O_82_4'].map({1:'Muy dictatorial', 2:'Dictatorial', 3:'Consultivo', 4:'Muy consultivo'}) #Se editan los registros de la columna "O_82_4", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_5'] = bd2017['O_82_5'].map({1:'Muy pasivo', 2:'Pasivo', 3:'Proactivo', 4:'Muy proactivo'}) #Se editan los registros de la columna "O_82_5", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_6'] = bd2017['O_82_6'].map({1:'Muy apático', 2:'Apático', 3:'Cooperativo', 4:'Muy cooperativo'}) #Se editan los registros de la columna "O_82_6", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_82_7'] = bd2017['O_82_7'].map({1:'Muy autosuficiente', 2:'Autosuficiente', 3:'Delegativo', 4:'Muy delegativo'}) #Se editan los registros de la columna "O_82_7", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_83_1'] = bd2017['O_83_1'].map({1:'Indígena', 2:'Afrodescendiente', 3:'LGTBI', 4:'Desplazados o víctimas del conflicto armado', 5:'Desmovilizados', 6:'Diversidad Funcional o discapacitado', 7:'Inmigrantes', 8:'Ninguno'}) #Se editan los registros de la columna "O_83_1", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_83_2'] = bd2017['O_83_2'].map({1:'Indígena', 2:'Afrodescendiente', 3:'LGTBI', 4:'Desplazados o víctimas del conflicto armado', 5:'Desmovilizados', 6:'Diversidad Funcional o discapacitado', 7:'Inmigrantes', 8:'Ninguno'}) #Se editan los registros de la columna "O_83_2", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017['O_88'] = bd2017['O_88'].map({1:'Hombre', 2:'Mujer', 3:'Otro'}) #Se editan los registros de la columna "O_88", traduciendo los códigos presentes en la base de datos por las opciones de respuesta originales.
bd2017 = bd2017.reset_index(drop=True) #Se reinicia el índice de la tabla
bd2017 = bd2017[["Edicion","S_1","O_88","O_89",
                 "O_12","O_13","O_22","O_67","O_68","O_8","O_19_1","O_19_2","O_19_3","O_19_4","O_19_5","O_19_6","O_19_7","O_19_8","O_19_9", 
                 "O_20_1","O_20_2","O_20_3","O_20_4","O_20_5","O_20_6","O_20_7","O_20_8","O_70_1","O_70_2","O_70_3","O_70_4",
                 "O_71_1","O_71_2","O_71_3","O_71_4",	"O_72_1","O_72_2","O_72_3","O_72_4","O_72_5","O_72_6","O_72_7",
                 "O_24","O_48","O_52","O_54","O_58","O_59","O_90","O_28_1","O_28_2","O_28_3","O_28_4","O_28_5","O_28_6","O_28_7","O_28_8",
                 "O_37_1","O_37_2","O_37_3","O_37_4","O_37_5","O_38_1","O_38_2","O_38_3","O_38_4","O_38_5","O_38_6","O_38_7","O_38_8","O_38_9",
                 "O_66_1","O_66_2","O_66_3","O_66_4","O_66_5","O_66_6","O_66_7","O_81_1","O_81_2","O_81_3","O_81_4","O_81_5","O_81_6","O_81_7",
                 "O_82_1","O_82_2","O_82_3","O_82_4","O_82_5","O_82_6","O_82_7",
                 "O_40","O_41","O_45","O_49","O_55","O_61_1","O_61_2","O_61_3","O_61_4","O_61_5","O_62_1","O_62_2","O_62_3","O_62_4","O_62_5","O_62_6"]]

bd2017['O_70'] = bd2017[bd2017.columns[27:31]].apply(    #Con este código, se unifica en una columna los datos de la O_70_1 a O_70_6.
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1)
bd2017['O_70'] = bd2017['O_70'].str.split(',').str[0]

bd2017['O_71'] = bd2017[bd2017.columns[31:35]].apply(    #Con este código, se unifica en una columna los datos de la O_71_1 a O_71_6.
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1)

bd2017['O_71'] = bd2017['O_71'].str.split(',').str[0]
bd2017 = bd2017.drop(columns = ["O_70_1","O_70_2","O_70_3","O_70_4","O_71_1","O_71_2","O_71_3","O_71_4"]) #Se eliminan las columnas que se unificaron previamente
bd2017
# np.array(bd2017.columns)
bd2017['O_71'].unique()
# Out:
# array(['', 'De fácil acceso', 'Clara y comprensible',
#        'Amplia y suficiente', 'De utilidad para el trabajo en la comuna'],
#       dtype=object)

# %%
IPCM_O_2017 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2017/2017 Organizaciones Indicador Global Gifi.csv', header=None) #Lectura del archivo donde están contenidos los resultados de la medición del año 2019 por cada organización (Índices y Subíndices)
IPCM_O_2017 = IPCM_O_2017.drop(range(0,10))
IPCM_O_2017 = IPCM_O_2017.rename(columns=IPCM_O_2017.iloc[0]) #Se cambia el nombre de las columnas a partir de la primera fila
IPCM_O_2017 = IPCM_O_2017.drop(IPCM_O_2017.index[0]) #Se elimina la primera fila para evitar duplicados
IPCM_O_2017 = IPCM_O_2017[['Orden','Global C','Global P','Global E','Indice de Participación 3']] #Se filtra la base de datos a partir de las columnas necesarias
IPCM_O_2017 = IPCM_O_2017.rename(columns={'Global C':'Condiciones Territoriales', 'Global P':'Prácticas', 'Global E':'Efectos','Indice de Participación 3':'IPCM'}) #Se renombran las columnas a partir de las dimensiones y el IPCM
IPCM_O_2017 = IPCM_O_2017.set_index('Orden', inplace = False) #Se convierte la columna Orden en el índice de la tabla
IPCM_O_2017 = IPCM_O_2017.reset_index(drop=True) #Se reinicia el índice de la tabla
IPCM_O_2017 = IPCM_O_2017.replace(',','.', regex=True)
IPCM_O_2017 = IPCM_O_2017.astype(float)
IPCM_O_2017
# Out:
#      Condiciones Territoriales  Prácticas   Efectos  IPCM
# 0                     0.701689   0.732380  0.467895  0.62
# 1                     0.648795   0.739776  0.453626  0.60
# 2                     0.412993   0.264599  0.365254  0.34
# 3                     0.509406   0.275729  0.242671  0.32
# 4                     0.285698   0.304252  0.435903  0.34
# ..                         ...        ...       ...   ...
# 597                   0.167130   0.230995  0.357662  0.24
# 598                   0.423048   0.581286  0.252108  0.40
# 599                   0.249178   0.632960  0.230478  0.33
# 600                   0.288389   0.662857  0.422667  0.43
# 601                   0.344312   0.480894  0.386662  0.40
#
# [602 rows x 4 columns]

# %%
bd2017 = pd.concat([bd2017,IPCM_O_2017], axis=1) #Se concatena las tablas de modo que se le agregue los subíndices por dimensión y el IPCM a la base de datos del IPCM
bd2017
# Out:
#      Edicion  S_1    O_88  O_89 O_12 O_13  O_22             O_67  \
# 0       2017   12  Hombre     5   Si   Si    70  Muy pocas veces
# 1       2017    3   Mujer     4   No   No     5     Casi siempre
# 2       2017    2  Hombre     0   No   Si     5  Muy pocas veces
# 3       2017   11  Hombre     3   No   No    70          Siempre
# 4       2017   13  Hombre     6   Si   Si    40    Algunas veces
# ..       ...  ...     ...   ...  ...  ...   ...              ...
# 597     2017    9   Mujer     1   No   No    30     Casi siempre
# 598     2017    5  Hombre     1   No   No    90     Casi siempre
# 599     2017    6  Hombre     1   No   No    90     Casi siempre
# 600     2017   15  Hombre     1   No   No    54     Casi siempre
# 601     2017   16   Mujer     1   No   No    30     Casi siempre
#
#                 O_68 O_8  ...                   O_62_3  \
# 0            Siempre  Si  ...               Equitativo
# 1       Casi siempre  No  ...  Totalmente inequitativo
# ...

# %%
bd2021 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2021/organizaciones_final.csv', delimiter=';', decimal='.') #Lectura del archivo con los datos de organizaciones sociales de 2021
bd2021 = bd2021.rename(columns={'O_20_other':'O_20_8', 'O_28_other':'O_28_8', 'O_72_other':'O_72_9'}) #Se renombran las columnas de modo que coincidan con las otras bases de datos.
bd2021.insert(0, "Edicion", 2021, allow_duplicates=False) #Se añade la columna "Edición" y se le otorga el registro 2021
bd2021 = bd2021[["Edicion","S_1","O_88","O_89",
                 "O_12","O_13","O_22","O_67","O_68","O_8","O_19_1","O_19_2","O_19_3","O_19_4","O_19_5","O_19_6","O_19_7","O_19_8","O_19_9", 
                 "O_20_1","O_20_2","O_20_3","O_20_4","O_20_5","O_20_6","O_20_7","O_20_8","O_70","O_71","O_72_1","O_72_2","O_72_3","O_72_4","O_72_5","O_72_6","O_72_7","O_72_8","O_72_9",
                 "O_24","O_48","O_52","O_54","O_58","O_59","O_90","O_28_1","O_28_2","O_28_3","O_28_4","O_28_5","O_28_6","O_28_7","O_28_8",
                 "O_37_1","O_37_2","O_37_3","O_37_4","O_37_5","O_38_1","O_38_2","O_38_3","O_38_4","O_38_5","O_38_6","O_38_7","O_38_8","O_38_9",
                 "O_66_1","O_66_2","O_66_3","O_66_4","O_66_5","O_66_6","O_66_7","O_81_1","O_81_2","O_81_3","O_81_4","O_81_5","O_81_6","O_81_7",
                 "O_82_1","O_82_2","O_82_3","O_82_4","O_82_5","O_82_6","O_82_7",
                 "O_40","O_41","O_45","O_49","O_55","O_61_1","O_61_2","O_61_3","O_61_4","O_61_5","O_62_1","O_62_2","O_62_3","O_62_4","O_62_5","O_62_6"]]
bd2021['S_1'] = bd2021['S_1'].str[0:2] #Se edita la columna "S_1" de modo que sólo se muestre el código de la comuna.
bd2021['S_1'] = bd2021['S_1'].replace('-','',regex=True) #Se eliminan los guiones en la columna "S_1"
bd2021 = bd2021.replace(np.nan, 'Sin registro', regex=True) #Se rellenan los datos vacíos con la sentencia "Sin registro"
bd2021['O_88'] = bd2021['O_88'].replace(['todos los integrantes','son dos, un hombre y una mujer','es un colectivo','colectivo', 'mixto'],'Sin registro')
bd2021
# bd2021['O_71'].unique()
# Out:
#       Edicion S_1    O_88 O_89 O_12 O_13  O_22             O_67  \
# 0        2021  11   Mujer   Sí   Sí   Sí    37    Algunas veces
# 1        2021   6   Mujer   Sí   Sí   Sí    62     Casi siempre
# 2        2021   1   Mujer   Sí   No   Sí     0    Algunas veces
# 3        2021  16  Hombre   Sí   No   Sí    10    Algunas veces
# 4        2021   6  Hombre   Sí   Sí   Sí    10      No consulta
# ...       ...  ..     ...  ...  ...  ...   ...              ...
# 1120     2021  11  Hombre   Sí   No   No    50      No consulta
# 1121     2021  11  Hombre   No   No   No    49      No consulta
# 1122     2021  11  Hombre   Sí   No   No    15      No consulta
# 1123     2021  11   Mujer   Sí   No   No    10      No consulta
# 1124     2021  10   Mujer   Sí   Sí   Sí    30  Muy pocas veces
#
#                  O_68 O_8  ...                 O_61_2                 O_61_3  \
# 0       Algunas veces  Sí  ...             Equitativo             Equitativo
# ...

# %%
IPCM_O_2021 = pd.read_csv(r'C:/Users/jlope/Documents/Maestría en Ingeniería - Analítica/Tesis/Modelos/Inputs/2021/ipcm_org_2021_microdatos_indice.csv',sep=';',decimal='.')
IPCM_O_2021 = IPCM_O_2021[['Subíndice Condiciones','Subíndice Prácticas','Subíndice Efectos','Indice Organizaciones']] #Se filtra la base de datos con las columnas que contienen los datos necesarios
IPCM_O_2021 = IPCM_O_2021.rename(columns={'Subíndice Condiciones':'Condiciones Territoriales', 'Subíndice Prácticas':'Prácticas', 'Subíndice Efectos':'Efectos', 'Indice Organizaciones':'IPCM'}) #Se renombran las columnas
IPCM_O_2021 = IPCM_O_2021.reset_index(drop=True)
IPCM_O_2021
# Out:
#       Condiciones Territoriales  Prácticas   Efectos      IPCM
# 0                      0.225295   0.625283  0.725748  0.467596
# 1                      0.337986   0.597656  0.591000  0.492394
# 2                      0.351116   0.535962  0.331659  0.396667
# 3                      0.480107   0.615416  0.787009  0.614935
# 4                      0.508938   0.660276  0.752054  0.632237
# ...                         ...        ...       ...       ...
# 1120                   0.604452   0.673724  0.785776  0.683986
# 1121                   0.656682   0.709377  0.751620  0.704818
# 1122                   0.668042   0.655933  0.770081  0.696199
# 1123                   0.685270   0.654565  0.743598  0.693507
# 1124                   0.431431   0.565930  0.608814  0.529728
#
# [1125 rows x 4 columns]

# %%
bd2021 = pd.concat([bd2021,IPCM_O_2021], axis=1) #Se concatenan las bases de datos de modo que se le añade los subíndices por dimensión y el IPCM a los datos de organizaciones
bd2021
# Out:
#       Edicion S_1    O_88 O_89 O_12 O_13  O_22             O_67  \
# 0        2021  11   Mujer   Sí   Sí   Sí    37    Algunas veces
# 1        2021   6   Mujer   Sí   Sí   Sí    62     Casi siempre
# 2        2021   1   Mujer   Sí   No   Sí     0    Algunas veces
# 3        2021  16  Hombre   Sí   No   Sí    10    Algunas veces
# 4        2021   6  Hombre   Sí   Sí   Sí    10      No consulta
# ...       ...  ..     ...  ...  ...  ...   ...              ...
# 1120     2021  11  Hombre   Sí   No   No    50      No consulta
# 1121     2021  11  Hombre   No   No   No    49      No consulta
# 1122     2021  11  Hombre   Sí   No   No    15      No consulta
# 1123     2021  11   Mujer   Sí   No   No    10      No consulta
# 1124     2021  10   Mujer   Sí   Sí   Sí    30  Muy pocas veces
#
#                  O_68 O_8  ...                 O_62_1                 O_62_2  \
# 0       Algunas veces  Sí  ...  Totalmente equitativo                Neutral
# ...

# %%
bdfinal = pd.concat([bd2019,bd2017,bd2021]) #Se concatenan los datos de organizaciones 2017 y 2019, de modo que se consolide en un sólo conjunto de datos los registros de organizaciones sociales
bdfinal = bdfinal.reset_index(drop=True) #Se reinicia el índice de la tabla
bdfinal['O_49'] = bdfinal['O_49'].replace(np.nan, 0, regex=True)
bdfinal['O_49'] = bdfinal['O_49'].replace('Sin registro', 0, regex=True)
bdfinal['O_55'] = bdfinal['O_55'].replace(np.nan, 0, regex=True)
bdfinal['O_20_8'] = bdfinal['O_20_8'].replace([-88,'-88'], 'Sin registro', regex=True)
bdfinal['O_20_8'] = bdfinal['O_20_8'].replace('0', 'Sin registro', regex=True)
bdfinal['O_20_8'] = bdfinal['O_20_8'].replace('2', 'Sin registro', regex=True)
bdfinal['O_20_8'] = bdfinal['O_20_8'].replace(['NO','N','NINGUNO','NOO','NINGUNA','NO DICE'], 'No', regex=False)
bdfinal['O_20_8'] = np.where((bdfinal.O_20_8 != 'No'), 'Si', bdfinal.O_20_8)
bdfinal['O_72_9'] = np.where((bdfinal.O_72_9 != 'No'), 'Si', bdfinal.O_72_9)
bdfinal['O_28_8'] = np.where((bdfinal.O_28_8 != 'No'), 'Si', bdfinal.O_28_8)
bdfinal['O_28_8'] = bdfinal['O_28_8'].replace([-88,'-88'], 'Sin registro', regex=True)
bdfinal['O_89'] = bdfinal['O_89'].replace('0', 'No', regex=True)
bdfinal['O_89'] = bdfinal['O_89'].replace('9999', 'No', regex=True)
bdfinal['O_89'] = np.where((bdfinal.O_89 != 'No'), 'Si', bdfinal.O_89)
bdfinal['O_52'] = bdfinal['O_52'].astype(int)
bdfinal['O_90'] = bdfinal['O_90'].astype(int)
bdfinal['O_55'] = bdfinal['O_55'].astype(int)
bdfinal['O_49'] = bdfinal['O_49'].astype(int)
bdfinal = bdfinal.replace(np.nan, 'Sin registro', regex=True)
bdfinal = bdfinal.replace('', 'Sin registro', regex=True)
bdfinal = bdfinal.replace(-88, 0, regex=True)
bdfinal = bdfinal.replace(-98, 0, regex=True)
bdfinal = bdfinal.replace(-99, 0, regex=True)
bdfinal = bdfinal.replace('Sí', 'Si', regex=True)

bdfinal.to_csv('BDOrganizacionesTotal.csv', index=False) #Se exportan los datos a un archivo .csv
bdfinal.to_excel('BDOrganizacionesTotal.xlsx', index=False) #Se exportan los datos a un archivo excel
# np.array(bdfinal.columns)
# bdfinal['O_71'].unique()
